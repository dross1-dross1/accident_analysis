# %% [markdown]
# Overview of the Dataset

# %%
df = read.csv("/content/sample_data/accident_data_pruned.csv")

# %%
head(df)
# Out:
#   severity time                lat      long      dist_mi is_right_side
# 1 3        2016-02-08 00:37:08 40.10891 -83.09286 3.230   1
# 2 2        2016-02-08 05:56:20 39.86542 -84.06280 0.747   1
# 3 2        2016-02-08 06:15:39 39.10266 -84.52468 0.055   1
# 4 2        2016-02-08 06:51:45 41.06213 -81.53784 0.123   1
# 5 3        2016-02-08 07:53:43 39.17239 -84.49279 0.500   1
# 6 2        2016-02-08 08:16:57 39.06324 -84.03243 1.427   1
#   city         county     state zip   ⋯ junction no_exit railway tcircle
# 1 Dublin       Franklin   OH    43017 ⋯ 0        0       0       0
# 2 Dayton       Montgomery OH    45424 ⋯ 0        0       0       0
# 3 Cincinnati   Hamilton   OH    45203 ⋯ 1        0       0       0
# 4 Akron        Summit     OH    44311 ⋯ 0        0       0       0
# 5 Cincinnati   Hamilton   OH    45217 ⋯ 0        0       0       0
# 6 Williamsburg Clermont   OH    45176 ⋯ 0        0       0       0
#   station stop tcalming tsignal turning_loop is_day
# ...

# %% [markdown]
# Subset of just Florida Now

# %%
#Just FLorida now 
florida_df = df[df$state == 'FL', ]

# %%
head(florida_df)

# %%
tail(florida_df)

# %%
dim(florida_df) #accidents from Florida
# Out:
# [1] 400885     31

# %%
library(dplyr)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
library(ggplot2)

# %% [markdown]
# Severity Analysis of the Entire Dataset

# %%
ggplot(df) +
  geom_bar(aes(x=severity))
# Out:
# plot without title

# %%
ggplot(florida_df) + #Florida only now
  geom_bar(aes(x=severity)) #Overall ther are mainly 2s, but 1s are the least common
# Out:
# plot without title

# %%
ggplot(florida_df, color =) + #Spread of distances across severity values
  geom_point(aes(x=severity, y=dist_mi, color = as.factor(severity)))
# Out:
# plot without title

# %% [markdown]
# Texas Now

# %%
texas_df = df[df$state == 'TX', ]

# %%
head(texas_df)
# Out:
#       severity time                lat      long      dist_mi is_right_side
# 11780 2        2016-11-30 15:29:48 32.84365 -96.77463 1.915   1
# 11781 2        2016-11-30 15:41:16 32.84662 -96.63736 0.021   1
# 11782 3        2016-11-30 15:15:48 32.86693 -96.66617 0.616   1
# 11785 2        2016-11-30 15:35:51 32.79426 -97.21214 0.470   1
# 11787 2        2016-11-30 16:16:05 32.81235 -97.31399 0.885   1
# 11788 3        2016-11-30 16:16:05 32.79385 -96.70278 0.502   1
#       city       county  state zip   ⋯ junction no_exit railway tcircle station
# 11780 Dallas     Dallas  TX    75205 ⋯ 1        0       0       0       0
# 11781 Dallas     Dallas  TX    75228 ⋯ 0        0       0       0       0
# 11782 Garland    Dallas  TX    75041 ⋯ 0        0       0       0       0
# 11785 Fort Worth Tarrant TX    76118 ⋯ 1        0       0       0       0
# 11787 Fort Worth Tarrant TX    76137 ⋯ 1        0       0       0       0
# ...

# %%
ggplot(texas_df) +
  geom_bar(aes(x=severity))
ggplot(texas_df, color =) + 
  geom_point(aes(x=severity, y=dist_mi, color = as.factor(severity)))
# Out:
# plot without title
# plot without title

# %% [markdown]
# Now California

# %%
california_df = df[df$state == 'CA', ]

# %%
head(california_df)
# Out:
#     severity time                lat      long      dist_mi is_right_side
# 989 3        2016-03-22 18:53:11 38.82584 -120.0292 0.121   0
# 990 2        2016-03-22 19:00:49 37.35821 -121.8400 0.259   1
# 991 3        2016-03-22 20:07:32 37.88194 -122.3080 0.276   1
# 992 2        2016-03-22 21:40:18 37.88104 -122.3078 0.170   1
# 993 2        2016-03-22 21:36:42 38.51881 -121.1017 0.000   1
# 994 2        2016-03-22 21:36:42 38.51881 -121.1017 0.000   1
#     city        county      state zip   ⋯ junction no_exit railway tcircle
# 989 Echo Lake   El Dorado   CA    95721 ⋯ 0        0       0       0
# 990 San Jose    Santa Clara CA    95116 ⋯ 0        0       0       0
# 991 Berkeley    Alameda     CA    94710 ⋯ 1        0       0       0
# 992 Berkeley    Alameda     CA    94710 ⋯ 0        0       0       0
# 993 Sloughhouse Sacramento  CA    95683 ⋯ 0        0       0       0
# 994 Sloughhouse Sacramento  CA    95683 ⋯ 0        0       0       0
# ...

# %%
ggplot(california_df) +
  geom_bar(aes(x=severity))
# Out:
# plot without title

# %%
ggplot(california_df, color =) + 
  geom_point(aes(x=severity, y=dist_mi, color = as.factor(severity)))
# Out:
# plot without title
